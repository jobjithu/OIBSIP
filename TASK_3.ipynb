# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/home/job/Downloads/Oasis data/Advertising.csv')
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
print('\n'+ "="*100)
print(df.shape)
print('\n'+ "="*100)
# Out:
# ...
# (200, 5)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
print('\n'+ "="*100)
print(df.columns)
print('\n'+ "="*100)
# Out:
# ...
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## ScatterPlot for TV and Sales

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df,x=df['TV'],y=df['Sales'],color = 'red')
plt.show()

# %% [markdown]
# ## scatterPlot for Radio and sales

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df,x=df['Radio'],y=df['Sales'])
plt.show()

# %% [markdown]
# # scatterPlot for Newspaper and sales

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df,x=df['Newspaper'],y=df['Sales'],color = 'green')
plt.show()

# %%
sns.pairplot(df,hue = 'Sales')
plt.show()

# %% [markdown]
# ## splitting the datset into X to the attributes and y to the target variable

# %%
x=df.drop('Sales',axis=1)
x
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 0             1  230.1   37.8       69.2
# 1             2   44.5   39.3       45.1
# 2             3   17.2   45.9       69.3
# 3             4  151.5   41.3       58.5
# 4             5  180.8   10.8       58.4
# ..          ...    ...    ...        ...
# 195         196   38.2    3.7       13.8
# 196         197   94.2    4.9        8.1
# 197         198  177.0    9.3        6.4
# 198         199  283.6   42.0       66.2
# 199         200  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
y=df['Sales']
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state = 0)
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## fitting the model to the dataset and predictions

# %%
model= LinearRegression()
model.fit(X_train,y_train)
y_predictions=model.predict(X_test)
y_predictions
# Out:
# array([10.24664397,  7.3067958 ,  7.01313011, 24.0629912 , 11.84538583,
#         6.3623126 , 12.97367539, 15.01392577, 10.95137181, 16.2302401 ,
#        22.94764396,  9.07892877, 10.29830431, 15.372556  , 11.63358138,
#        12.38729183, 18.91996453, 10.72601207, 16.03372676, 17.36589369,
#        23.85225051,  9.51048184, 15.25366204, 12.2528663 ,  5.81346738,
#        15.19998588, 12.12398331, 20.74762723, 13.36651757,  9.16548788,
#        13.0430809 , 21.47977498, 18.01828076, 21.14170908,  6.74096317,
#         5.9527019 ,  7.82515133, 13.21661502, 14.72150697,  6.18172688])

# %% [markdown]
# ## Lets evaluate the model for its accuracy using various metrics such as RMSE,MAE and R-Squared

# %%
from sklearn import metrics

print('MAE:',metrics.mean_absolute_error(y_predictions,y_test))
print('\n'+ "="*100)
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_predictions,y_test)))
print('\n'+ "="*100)
print('R-Squared',metrics.r2_score(y_predictions,y_test))
print('\n'+ "="*100)
# Out:
# MAE: 1.415848086831749
#
# ...
# RMSE: 2.125203007295873
#
# ...
# R-Squared 0.8283777385812962
#
# ...
